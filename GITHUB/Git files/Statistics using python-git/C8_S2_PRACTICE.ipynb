# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
#TASK1
df= pd.read_csv('DS1_C8_S2_SmartCarRiding_Data_Practice.csv')
df
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 0       24238194  52:06.0          7.5  2015-05-07 19:52:06 UTC
# 1       27835199  04:56.0          7.7  2009-07-17 20:04:56 UTC
# 2       44984355  45:00.0         12.9  2009-08-24 21:45:00 UTC
# 3       25894730  22:21.0          5.3  2009-06-26 08:22:21 UTC
# 4       17610152  47:00.0         16.0  2014-08-28 17:47:00 UTC
# ...          ...      ...          ...                      ...
# 199995  42598914  49:00.0          3.0  2012-10-28 10:49:00 UTC
# 199996  16382965  09:00.0          7.5  2014-03-14 01:09:00 UTC
# 199997  27804658  42:00.0         30.9  2009-06-29 00:42:00 UTC
# 199998  20259894  56:25.0         14.5  2015-05-20 14:56:25 UTC
# 199999  11951496  08:00.0         14.1  2010-05-15 04:08:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.999817        40.738354         -73.999512
# 1             -73.994355        40.728225         -73.994710
# ...

# %%
print(df.columns)
fare_amount = df[['fare_amount']]
fare_amount
# Out:
# Index(['Index', 'key', 'fare_amount', 'pickup_datetime', 'pickup_longitude',
#        'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
#        'passenger_count'],
#       dtype='object')
#         fare_amount
# 0               7.5
# 1               7.7
# 2              12.9
# 3               5.3
# 4              16.0
# ...             ...
# 199995          3.0
# 199996          7.5
# 199997         30.9
# 199998         14.5
# 199999         14.1
#
# [200000 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df.boxplot(column=['Index','fare_amount','pickup_longitude','pickup_latitude','dropoff_longitude','dropoff_latitude','passenger_count'],grid=False,figsize=(15,8))
plt.show()

# %%
def outliers(col):
    ser=pd.Series(df[col])
    q1=ser.quantile(0.25)
    q3=ser.quantile(0.75)
    iqr=q3-q1
    uf=q3+1.5*iqr
    lf=q1-1.5*iqr
    for z in ser:
        if z>uf or z<lf:
            df[col]=df[col].replace([z],df[col].mean())

# %%
df.boxplot(column=['fare_amount'],grid=False,figsize=(15,8))
plt.show()

# %%
outliers('fare_amount')

# %%
df.boxplot(column=['fare_amount'],grid=False,figsize=(15,8))
plt.show()

# %%
outliers('fare_amount')

# %%
df.boxplot(column=['fare_amount'],grid=False,figsize=(15,8))
plt.show()

# %%
outliers('fare_amount')

# %%
df.boxplot(column=['fare_amount'],grid=False,figsize=(15,8))
plt.show()

# %%
outliers('fare_amount')

# %%
df.boxplot(column=['fare_amount'],grid=False,figsize=(15,8))
plt.show()

# %%
#TASK3
#10 15 30 200 1000 5000 10000 50000 100000
num = [10,15,30,200,1000,5000,10000,50000,100000]
data_s = []
fig,ax = plt.subplots(3,3,figsize=(14,10))
for i in num:
    sample_df=fare_amount.sample(n=i,replace=True,random_state=1)
    data_s.append(sample_df['fare_amount'])
k=0
for i in range(0,3):
    for j in range(0,3):
        ax[i,j].hist(data_s[k],bins=10,density=True)
        ax[i,j].set_title(label='Sample_size='+str(len(data_s[k])))
        k=k+1
plt.show()

# %% [markdown]
# #interpretation
# For Sample Sizes 200 and Above (200, 1000, 5000, 10000, 50000, 100000):
#
# As the sample size increases, the distribution becomes smoother and more closely resembles a normal distribution due to the Central Limit Theorem.
# By the time the sample size reaches 1000 or more, the distribution is likely nearly normal, even if the population itself isn’t perfectly normal.
# Larger sample sizes reduce the impact of random variability and provide a more accurate representation of the population.

# %%
#TASK4
sample_200 = df.sample(n=200,replace = True , random_state = 1)
sample_200
# Out:
#            Index      key  fare_amount          pickup_datetime  \
# 128037  34880869  32:56.0     11.25193  2010-12-26 14:32:56 UTC
# 5192    10514640  28:00.0     14.00000  2012-11-27 21:28:00 UTC
# 50057   39371632  09:00.0     12.90000  2010-08-23 22:09:00 UTC
# 109259  37753824  22:30.0      6.00000  2013-10-09 08:22:30 UTC
# 73349   48099710  23:07.0      6.10000  2012-01-17 20:23:07 UTC
# ...          ...      ...          ...                      ...
# 119440  38653342  29:00.0      7.70000  2011-01-15 13:29:00 UTC
# 176028  16314367  26:00.0      4.50000  2009-04-23 13:26:00 UTC
# 38122   37151879  57:00.0     13.00000  2013-12-19 20:57:00 UTC
# 15917    4467260  52:26.0      4.50000  2012-08-14 02:52:26 UTC
# 20931   17816586  10:00.0     10.00000  2014-04-25 08:10:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 128037        -73.965069        40.791239         -73.782221
# 5192          -73.776675        40.645348         -73.819305
# ...

# %%
#TASK5
sample_df1 = pd.DataFrame()
for i in range(0,20):
    sample_df1['sample_' +str(i)] = df['fare_amount'].sample(n=200, replace = True).reset_index(drop = True)
sample_df1
# Out:
#       sample_0  sample_1   sample_2  sample_3  sample_4   sample_5   sample_6  \
# 0     4.000000       8.5  11.500000       5.3       6.5   8.900000   8.979242
# 1    15.000000       6.5   8.670463       7.5       8.5   4.500000   9.700000
# 2    11.168143      10.1  12.000000       9.3       9.5   4.500000   5.700000
# 3    13.300000       8.1   9.500000       8.5      10.1   6.500000   6.100000
# 4     8.979242       6.1   5.300000       9.5      11.5  15.000000   4.900000
# ..         ...       ...        ...       ...       ...        ...        ...
# 195  11.500000       6.0  11.000000       4.9      13.3  13.300000   4.500000
# 196  10.100000       7.3   4.000000       9.7       6.1  11.109421  12.000000
# 197  10.500000       5.3   8.919740       6.9      12.9   5.300000   7.700000
# 198   8.900000       6.9  12.500000      11.7       8.9  10.500000   6.900000
# 199   3.500000      10.0   9.000000      13.7       3.3   4.100000   9.300000
#
# ...

# %%
sample_mean = []
sample_name = sample_df1.columns
for i in sample_name:
    sample_mean.append(sample_df1[i].mean())

sample_mean_s = pd.DataFrame()
sample_mean_s.insert(0,'sample_name',sample_name)
sample_mean_s.insert(1,'sample_mean',sample_mean)
print(sample_mean_s)
# Out:
#    sample_name  sample_mean
# 0     sample_0     8.277117
# 1     sample_1     8.583163
# 2     sample_2     8.229305
# 3     sample_3     8.836443
# 4     sample_4     8.551506
# 5     sample_5     8.504118
# 6     sample_6     8.422463
# 7     sample_7     8.341045
# 8     sample_8     8.397410
# 9     sample_9     8.670694
# 10   sample_10     8.848216
# 11   sample_11     8.330040
# 12   sample_12     8.560460
# 13   sample_13     8.503756
# 14   sample_14     8.555130
# 15   sample_15     8.634734
# 16   sample_16     8.655381
# 17   sample_17     8.844224
# 18   sample_18     8.486653
# 19   sample_19     8.640857

# %%
import statistics as st
import scipy.stats as sts
from scipy.stats import kurtosis

# %%
#population parameters
mean_p = df['fare_amount'].mean()
print('Population mean is:',mean_p)
median_p = df['fare_amount'].median()
print('Population median is:',median_p)
std_p = st.stdev(df['fare_amount'])
print('Population std is:',std_p)
skew_p = sts.skew((df['fare_amount']), bias = False)
print('Population skewness is:',skew_p)
kurtosis_p = kurtosis((df['fare_amount']), bias = False)
print('Population kurtosis is:',kurtosis_p )
# Out:
# Population mean is: 8.507131515482902
# Population median is: 8.5
# Population std is: 3.1592616239346887
# Population skewness is: 0.5289349990856437
# Population kurtosis is: -0.2247477639423292

# %%
sample200 = df[['fare_amount']].sample(n=200 , replace = True, random_state=1,ignore_index=True)
sample200
# Out:
#      fare_amount
# 0       11.25193
# 1       14.00000
# 2       12.90000
# 3        6.00000
# 4        6.10000
# ..           ...
# 195      7.70000
# 196      4.50000
# 197     13.00000
# 198      4.50000
# 199     10.00000
#
# [200 rows x 1 columns]

# %%
#sample200 parameters
mean_s = st.mean(sample200['fare_amount'])
print("sample200 mean is:", mean_s)
median_s = st.median(sample200['fare_amount'])
print("sample200 median is:", median_s)
std_s = st.stdev(sample200['fare_amount'])
print("sample200 std is:", std_s)
skew_s = sts.skew(sample200['fare_amount'], bias = False)
print('sample200 skewness is:',skew_s)
kurtosis_s = kurtosis(sample200['fare_amount'], bias = False)
print('sample200 kurtosis is:',kurtosis_s)
# Out:
# sample200 mean is: 8.592899947089352
# sample200 median is: 8.5
# sample200 std is: 3.174727328294172
# sample200 skewness is: 0.5419399971647388
# sample200 kurtosis is: -0.3784460526900557

# %%
sample20_std = st.stdev(sample_mean_s['sample_mean'])
sample20_std
# Out:
# 0.18009429760416298

# %%
import math as m

# %%
std_p/m.sqrt(200)
# Out:
# 0.22339353178266427

# %% [markdown]
# #interpretation
# Mean & Median:
# The average (mean) and middle value (median) are nearly the same for both the population and the sample of 200.
# Kurtosis & Skewness:
# The sample has some bias and is slightly stretched to the right (positively skewed).
# The population has lighter tails (kurtosis ~ 0.6) and is also slightly stretched to the right.
# Standard Deviation:
# The variation in the sample mean (from 20 numbers) is about the same as the sample's standard deviation divided by the square root of the sample size.
# Shape of Distribution:
# The population and the sample of 200 don’t look like a normal (bell-shaped) curve and have lighter tails. The sample’s shape is somewhat similar to the population, but not exactly the same.
